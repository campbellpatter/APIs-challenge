# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 592

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#opening csv file
with open(output_data_file, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=',')
    #header
    csvwriter.writerow(['City', 'Cloudiness', 'Country', 'Date', 'Humidity','Lat','Lng','Max Temp','Wind Speed'])
    
    #count and setcount iterators
    count = 0
    setcount = 1
    
    #loop through cities from citipy
    print('Beginning Data Retrieval\n-----------------------------')
    for city in cities:
        count += 1
        
        #pull data from api for this city
        url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&APPID={api_key}"
        response = requests.get(url).json()

        #ignore cities not found
        if response['cod'] == '404':
            message = 'City not found. Skipping...'   #message to print
            
        #if found, create csv elements
        else:
            temp = response['main']['temp_max']
            maxtemp = (temp - 273.15) * 9/5 + 32 #converting kelvin to fahrenheit
            message = f'Processing Record {count} of Set {setcount} | {city}'  #message to print
            
            #write row of elements from response json elements
            csvwriter.writerow([response['name'], response['clouds']['all'], response['sys']['country'], response['dt'], response['main']['humidity'], response['coord']['lat'], response['coord']['lon'], maxtemp, response['wind']['speed']])

        print(message)
        
        #start new set every 50 cities
        if count%50 == 0:
            setcount += 1
            count = 0

    print("-----------------------------\nData Retrieval Complete\n-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | tautira
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | kavieng
# Processing Record 7 of Set 1 | alindao
# Processing Record 8 of Set 1 | tiksi
# City not found. Skipping...
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | russell
# City not found. Skipping...
# Processing Record 13 of Set 1 | jabinyanah
# Processing Record 14 of Set 1 | jambi
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | gavle
# City not found. Skipping...
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | dikson
# Processing Record 20 of Set 1 | monrovia
# Processing Record 21 of Set 1 | ixtapa
# Processing Record 22 of Set 1 | tasiilaq
# Processing Record 23 of Set 1 | tawau
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | vao
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | tadine
# Processing Record 28 of Set 1 | yellowknife
# City not found. Skipping...
# Processing Record 30 of Set 1 | oga
# Processing Record 31 of Set 1 | suzun
# Processing Record 32 of Set 1 | boguchany
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | klaksvik
# Processing Record 35 of Set 1 | waipawa
# Processing Record 36 of Set 1 | belturbet
# Processing Record 37 of Set 1 | east london
# Processing Record 38 of Set 1 | souillac
# Processing Record 39 of Set 1 | chuy
# Processing Record 40 of Set 1 | san-pedro
# Processing Record 41 of Set 1 | meulaboh
# City not found. Skipping...
# Processing Record 43 of Set 1 | den helder
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | pevek
# Processing Record 46 of Set 1 | san quintin
# Processing Record 47 of Set 1 | talara
# City not found. Skipping...
# Processing Record 49 of Set 1 | idritsa
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | prattville
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | torbay
# Processing Record 6 of Set 2 | butaritari
# Processing Record 7 of Set 2 | bambous virieux
# Processing Record 8 of Set 2 | sinnamary
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | aranos
# Processing Record 11 of Set 2 | belaya gora
# Processing Record 12 of Set 2 | kaitangata
# Processing Record 13 of Set 2 | trelew
# Processing Record 14 of Set 2 | coruripe
# Processing Record 15 of Set 2 | hobart
# Processing Record 16 of Set 2 | hervey bay
# Processing Record 17 of Set 2 | atar
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | new norfolk
# Processing Record 20 of Set 2 | barrow
# Processing Record 21 of Set 2 | nicoya
# Processing Record 22 of Set 2 | katsuura
# Processing Record 23 of Set 2 | verkhoyansk
# Processing Record 24 of Set 2 | thompson
# Processing Record 25 of Set 2 | khatanga
# Processing Record 26 of Set 2 | owensboro
# Processing Record 27 of Set 2 | banjar
# Processing Record 28 of Set 2 | basco
# City not found. Skipping...
# Processing Record 30 of Set 2 | carnarvon
# Processing Record 31 of Set 2 | bull savanna
# Processing Record 32 of Set 2 | lagoa
# Processing Record 33 of Set 2 | banting
# Processing Record 34 of Set 2 | sauda
# City not found. Skipping...
# Processing Record 36 of Set 2 | tura
# City not found. Skipping...
# Processing Record 38 of Set 2 | comodoro rivadavia
# Processing Record 39 of Set 2 | lucapa
# Processing Record 40 of Set 2 | igarka
# Processing Record 41 of Set 2 | eunice
# Processing Record 42 of Set 2 | avarua
# Processing Record 43 of Set 2 | avera
# Processing Record 44 of Set 2 | freeport
# Processing Record 45 of Set 2 | jega
# Processing Record 46 of Set 2 | zhezkazgan
# Processing Record 47 of Set 2 | upernavik
# Processing Record 48 of Set 2 | abeche
# Processing Record 49 of Set 2 | onguday
# Processing Record 50 of Set 2 | hilo
# Processing Record 1 of Set 3 | dzaoudzi
# City not found. Skipping...
# Processing Record 3 of Set 3 | kulhudhuffushi
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | wuda
# Processing Record 6 of Set 3 | nouadhibou
# Processing Record 7 of Set 3 | necochea
# Processing Record 8 of Set 3 | okakarara
# Processing Record 9 of Set 3 | wasilla
# City not found. Skipping...
# Processing Record 11 of Set 3 | xiamen
# Processing Record 12 of Set 3 | luba
# Processing Record 13 of Set 3 | mahebourg
# Processing Record 14 of Set 3 | mahibadhoo
# Processing Record 15 of Set 3 | lusambo
# Processing Record 16 of Set 3 | sabang
# Processing Record 17 of Set 3 | clyde river
# Processing Record 18 of Set 3 | pontes e lacerda
# City not found. Skipping...
# Processing Record 20 of Set 3 | auki
# Processing Record 21 of Set 3 | dingle
# Processing Record 22 of Set 3 | luderitz
# City not found. Skipping...
# Processing Record 24 of Set 3 | atuona
# Processing Record 25 of Set 3 | georgetown
# Processing Record 26 of Set 3 | saskylakh
# Processing Record 27 of Set 3 | port elizabeth
# City not found. Skipping...
# Processing Record 29 of Set 3 | moosomin
# Processing Record 30 of Set 3 | el tigre
# Processing Record 31 of Set 3 | geraldton
# Processing Record 32 of Set 3 | roald
# Processing Record 33 of Set 3 | anadyr
# Processing Record 34 of Set 3 | darhan
# City not found. Skipping...
# Processing Record 36 of Set 3 | lompoc
# Processing Record 37 of Set 3 | san jose
# Processing Record 38 of Set 3 | bilecik
# Processing Record 39 of Set 3 | trincomalee
# Processing Record 40 of Set 3 | lebu
# Processing Record 41 of Set 3 | filingue
# City not found. Skipping...
# Processing Record 43 of Set 3 | hyeres
# City not found. Skipping...
# Processing Record 45 of Set 3 | marsh harbour
# Processing Record 46 of Set 3 | amuntai
# Processing Record 47 of Set 3 | poum
# Processing Record 48 of Set 3 | beloha
# Processing Record 49 of Set 3 | hofn
# Processing Record 50 of Set 3 | aklavik
# Processing Record 1 of Set 4 | cidreira
# Processing Record 2 of Set 4 | beckley
# Processing Record 3 of Set 4 | nemuro
# Processing Record 4 of Set 4 | mar del plata
# Processing Record 5 of Set 4 | esperance
# City not found. Skipping...
# Processing Record 7 of Set 4 | lavrentiya
# Processing Record 8 of Set 4 | sao filipe
# City not found. Skipping...
# Processing Record 10 of Set 4 | ankang
# Processing Record 11 of Set 4 | baniyas
# City not found. Skipping...
# Processing Record 13 of Set 4 | alofi
# Processing Record 14 of Set 4 | mogadishu
# Processing Record 15 of Set 4 | mbanza-ngungu
# Processing Record 16 of Set 4 | kohima
# City not found. Skipping...
# Processing Record 18 of Set 4 | severo-kurilsk
# Processing Record 19 of Set 4 | solnechnyy
# Processing Record 20 of Set 4 | sorland
# Processing Record 21 of Set 4 | cape town
# Processing Record 22 of Set 4 | gat
# Processing Record 23 of Set 4 | leshukonskoye
# Processing Record 24 of Set 4 | pochutla
# Processing Record 25 of Set 4 | dubbo
# Processing Record 26 of Set 4 | labuhan
# Processing Record 27 of Set 4 | margate
# Processing Record 28 of Set 4 | olga
# Processing Record 29 of Set 4 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 31 of Set 4 | vila franca do campo
# City not found. Skipping...
# Processing Record 33 of Set 4 | puerto carreno
# Processing Record 34 of Set 4 | makakilo city
# Processing Record 35 of Set 4 | norman wells
# Processing Record 36 of Set 4 | prachuap khiri khan
# Processing Record 37 of Set 4 | pombas
# Processing Record 38 of Set 4 | nome
# Processing Record 39 of Set 4 | kodiak
# Processing Record 40 of Set 4 | fortuna
# City not found. Skipping...
# Processing Record 42 of Set 4 | saint-pierre
# Processing Record 43 of Set 4 | chenzhou
# Processing Record 44 of Set 4 | la asuncion
# Processing Record 45 of Set 4 | caravelas
# City not found. Skipping...
# Processing Record 47 of Set 4 | goundam
# Processing Record 48 of Set 4 | college
# Processing Record 49 of Set 4 | presidencia roque saenz pena
# City not found. Skipping...
# Processing Record 1 of Set 5 | frontera
# Processing Record 2 of Set 5 | takoradi
# Processing Record 3 of Set 5 | grindavik
# City not found. Skipping...
# Processing Record 5 of Set 5 | laguna
# City not found. Skipping...
# Processing Record 7 of Set 5 | kahului
# City not found. Skipping...
# Processing Record 9 of Set 5 | novominskaya
# Processing Record 10 of Set 5 | arraial do cabo
# Processing Record 11 of Set 5 | nanortalik
# Processing Record 12 of Set 5 | chokurdakh
# Processing Record 13 of Set 5 | chicama
# Processing Record 14 of Set 5 | srednekolymsk
# Processing Record 15 of Set 5 | kudahuvadhoo
# Processing Record 16 of Set 5 | goderich
# Processing Record 17 of Set 5 | faanui
# Processing Record 18 of Set 5 | inuvik
# Processing Record 19 of Set 5 | swellendam
# Processing Record 20 of Set 5 | jacareacanga
# Processing Record 21 of Set 5 | miandoab
# Processing Record 22 of Set 5 | rawson
# Processing Record 23 of Set 5 | mufulira
# Processing Record 24 of Set 5 | riyadh
# Processing Record 25 of Set 5 | sobolevo
# Processing Record 26 of Set 5 | ca mau
# Processing Record 27 of Set 5 | nikolskoye
# Processing Record 28 of Set 5 | henties bay
# Processing Record 29 of Set 5 | vanavara
# Processing Record 30 of Set 5 | betsiamites
# Processing Record 31 of Set 5 | iqaluit
# Processing Record 32 of Set 5 | worthing
# Processing Record 33 of Set 5 | amapa
# Processing Record 34 of Set 5 | kloulklubed
# Processing Record 35 of Set 5 | praya
# City not found. Skipping...
# Processing Record 37 of Set 5 | coquimbo
# Processing Record 38 of Set 5 | muli
# City not found. Skipping...
# Processing Record 40 of Set 5 | halifax
# Processing Record 41 of Set 5 | tilichiki
# Processing Record 42 of Set 5 | bukachacha
# Processing Record 43 of Set 5 | jieshi
# Processing Record 44 of Set 5 | todos santos
# Processing Record 45 of Set 5 | sambava
# Processing Record 46 of Set 5 | clarksburg
# Processing Record 47 of Set 5 | baft
# Processing Record 48 of Set 5 | ayacucho
# City not found. Skipping...
# Processing Record 50 of Set 5 | cayenne
# Processing Record 1 of Set 6 | pingliang
# Processing Record 2 of Set 6 | oxford
# Processing Record 3 of Set 6 | erenhot
# Processing Record 4 of Set 6 | sisimiut
# Processing Record 5 of Set 6 | constitucion
# Processing Record 6 of Set 6 | laguna de perlas
# Processing Record 7 of Set 6 | provideniya
# Processing Record 8 of Set 6 | mitsamiouli
# Processing Record 9 of Set 6 | marawi
# Processing Record 10 of Set 6 | namibe
# Processing Record 11 of Set 6 | weinan
# Processing Record 12 of Set 6 | bambanglipuro
# Processing Record 13 of Set 6 | camacha
# Processing Record 14 of Set 6 | ayan
# Processing Record 15 of Set 6 | port-cartier
# Processing Record 16 of Set 6 | narsaq
# City not found. Skipping...
# Processing Record 18 of Set 6 | indramayu
# Processing Record 19 of Set 6 | ancud
# Processing Record 20 of Set 6 | oroville
# Processing Record 21 of Set 6 | gillette
# Processing Record 22 of Set 6 | nanakuli
# Processing Record 23 of Set 6 | saint george
# Processing Record 24 of Set 6 | huilong
# Processing Record 25 of Set 6 | pinerovka
# Processing Record 26 of Set 6 | pangody
# Processing Record 27 of Set 6 | dharchula
# Processing Record 28 of Set 6 | oranjemund
# Processing Record 29 of Set 6 | banikoara
# Processing Record 30 of Set 6 | morbach
# Processing Record 31 of Set 6 | cabedelo
# Processing Record 32 of Set 6 | karratha
# Processing Record 33 of Set 6 | shubarkuduk
# Processing Record 34 of Set 6 | mawlaik
# Processing Record 35 of Set 6 | acapulco
# Processing Record 36 of Set 6 | salalah
# Processing Record 37 of Set 6 | husavik
# Processing Record 38 of Set 6 | skjervoy
# Processing Record 39 of Set 6 | bandarbeyla
# Processing Record 40 of Set 6 | belo oriente
# Processing Record 41 of Set 6 | altay
# Processing Record 42 of Set 6 | zilair
# Processing Record 43 of Set 6 | ust-maya
# Processing Record 44 of Set 6 | hasaki
# Processing Record 45 of Set 6 | stephenville
# Processing Record 46 of Set 6 | arroyo
# Processing Record 47 of Set 6 | hukuntsi
# Processing Record 48 of Set 6 | buala
# Processing Record 49 of Set 6 | bethel
# Processing Record 50 of Set 6 | ladario
# Processing Record 1 of Set 7 | codrington
# Processing Record 2 of Set 7 | berlevag
# Processing Record 3 of Set 7 | cabo san lucas
# Processing Record 4 of Set 7 | tazovskiy
# Processing Record 5 of Set 7 | victoria
# Processing Record 6 of Set 7 | outjo
# Processing Record 7 of Set 7 | impfondo
# Processing Record 8 of Set 7 | richards bay
# Processing Record 9 of Set 7 | santa maria
# City not found. Skipping...
# Processing Record 11 of Set 7 | yulara
# Processing Record 12 of Set 7 | mahon
# City not found. Skipping...
# Processing Record 14 of Set 7 | kruisfontein
# Processing Record 15 of Set 7 | taoudenni
# Processing Record 16 of Set 7 | phalaborwa
# Processing Record 17 of Set 7 | sabratah
# Processing Record 18 of Set 7 | saint-philippe
# Processing Record 19 of Set 7 | porto walter
# Processing Record 20 of Set 7 | lensk
# City not found. Skipping...
# Processing Record 22 of Set 7 | palmer
# Processing Record 23 of Set 7 | erzin
# City not found. Skipping...
# Processing Record 25 of Set 7 | wajima
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 7 | midyat
# Processing Record 30 of Set 7 | fergus falls
# Processing Record 31 of Set 7 | xixiang
# Processing Record 32 of Set 7 | davila
# City not found. Skipping...
# Processing Record 34 of Set 7 | khangarh
# Processing Record 35 of Set 7 | rocha
# Processing Record 36 of Set 7 | valparaiso
# Processing Record 37 of Set 7 | bilibino
# Processing Record 38 of Set 7 | nabire
# Processing Record 39 of Set 7 | caohai
# Processing Record 40 of Set 7 | kargasok
# Processing Record 41 of Set 7 | san cristobal
# Processing Record 42 of Set 7 | gboko
# Processing Record 43 of Set 7 | south lake tahoe
# Processing Record 44 of Set 7 | uyskoye
# Processing Record 45 of Set 7 | mayo
# Processing Record 46 of Set 7 | itaueira
# Processing Record 47 of Set 7 | tessalit
# Processing Record 48 of Set 7 | mandalgovi
# Processing Record 49 of Set 7 | north bend
# Processing Record 50 of Set 7 | batticaloa
# Processing Record 1 of Set 8 | qitaihe
# Processing Record 2 of Set 8 | omsukchan
# Processing Record 3 of Set 8 | aktau
# Processing Record 4 of Set 8 | sitka
# Processing Record 5 of Set 8 | ostrovnoy
# Processing Record 6 of Set 8 | airai
# Processing Record 7 of Set 8 | bereda
# Processing Record 8 of Set 8 | pahalgam
# Processing Record 9 of Set 8 | borovskoy
# Processing Record 10 of Set 8 | te anau
# Processing Record 11 of Set 8 | paamiut
# City not found. Skipping...
# Processing Record 13 of Set 8 | torata
# Processing Record 14 of Set 8 | topeka
# City not found. Skipping...
# Processing Record 16 of Set 8 | matagami
# Processing Record 17 of Set 8 | flin flon
# Processing Record 18 of Set 8 | ostersund
# Processing Record 19 of Set 8 | pangnirtung
# City not found. Skipping...
# Processing Record 21 of Set 8 | tyup
# Processing Record 22 of Set 8 | letychiv
# Processing Record 23 of Set 8 | katangli
# Processing Record 24 of Set 8 | feltre
# Processing Record 25 of Set 8 | savelugu
# Processing Record 26 of Set 8 | fairbanks
# City not found. Skipping...
# Processing Record 28 of Set 8 | vaitape
# Processing Record 29 of Set 8 | alugan
# Processing Record 30 of Set 8 | shurugwi
# Processing Record 31 of Set 8 | merauke
# Processing Record 32 of Set 8 | el mante
# Processing Record 33 of Set 8 | vestmannaeyjar
# Processing Record 34 of Set 8 | lethem
# Processing Record 35 of Set 8 | pilar
# Processing Record 36 of Set 8 | nizwa
# Processing Record 37 of Set 8 | gimli
# Processing Record 38 of Set 8 | broome
# City not found. Skipping...
# Processing Record 40 of Set 8 | khor
# Processing Record 41 of Set 8 | khislavichi
# Processing Record 42 of Set 8 | isangel
# Processing Record 43 of Set 8 | okhotsk
# Processing Record 44 of Set 8 | high level
# Processing Record 45 of Set 8 | shelburne
# Processing Record 46 of Set 8 | nara
# Processing Record 47 of Set 8 | seybaplaya
# Processing Record 48 of Set 8 | havre
# Processing Record 49 of Set 8 | gornozavodsk
# Processing Record 50 of Set 8 | lawigan
# Processing Record 1 of Set 9 | kavaratti
# Processing Record 2 of Set 9 | zhanaozen
# Processing Record 3 of Set 9 | balabac
# Processing Record 4 of Set 9 | khash
# Processing Record 5 of Set 9 | adrar
# Processing Record 6 of Set 9 | balabagan
# Processing Record 7 of Set 9 | livadiya
# Processing Record 8 of Set 9 | shingu
# City not found. Skipping...
# Processing Record 10 of Set 9 | churapcha
# Processing Record 11 of Set 9 | yinchuan
# Processing Record 12 of Set 9 | teya
# Processing Record 13 of Set 9 | hami
# Processing Record 14 of Set 9 | arlit
# Processing Record 15 of Set 9 | pampierstad
# Processing Record 16 of Set 9 | yelizovo
# Processing Record 17 of Set 9 | flinders
# City not found. Skipping...
# Processing Record 19 of Set 9 | rio grande
# Processing Record 20 of Set 9 | qeshm
# Processing Record 21 of Set 9 | nelson bay
# Processing Record 22 of Set 9 | port hedland
# Processing Record 23 of Set 9 | faya
# Processing Record 24 of Set 9 | iquique
# Processing Record 25 of Set 9 | jinka
# Processing Record 26 of Set 9 | cuamba
# Processing Record 27 of Set 9 | ilulissat
# Processing Record 28 of Set 9 | svetlogorsk
# Processing Record 29 of Set 9 | saint-augustin
# Processing Record 30 of Set 9 | bilma
# Processing Record 31 of Set 9 | mareeba
# Processing Record 32 of Set 9 | melfi
# Processing Record 33 of Set 9 | kuytun
# City not found. Skipping...
# Processing Record 35 of Set 9 | mlyniv
# City not found. Skipping...
# Processing Record 37 of Set 9 | la ronge
# Processing Record 38 of Set 9 | obo
# Processing Record 39 of Set 9 | wao
# Processing Record 40 of Set 9 | petropavlovsk-kamchatskiy
# City not found. Skipping...
# Processing Record 42 of Set 9 | vangaindrano
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 9 | inhambane
# Processing Record 46 of Set 9 | jalu
# Processing Record 47 of Set 9 | tolyatti
# Processing Record 48 of Set 9 | biak
# Processing Record 49 of Set 9 | harper
# City not found. Skipping...
# Processing Record 1 of Set 10 | ayia galini
# Processing Record 2 of Set 10 | sylva
# Processing Record 3 of Set 10 | bestobe
# Processing Record 4 of Set 10 | lakatoro
# Processing Record 5 of Set 10 | coihaique
# Processing Record 6 of Set 10 | port lincoln
# Processing Record 7 of Set 10 | nadym
# Processing Record 8 of Set 10 | eureka
# Processing Record 9 of Set 10 | serra talhada
# Processing Record 10 of Set 10 | belmonte
# Processing Record 11 of Set 10 | naze
# Processing Record 12 of Set 10 | murmansk
# Processing Record 13 of Set 10 | vanimo
# Processing Record 14 of Set 10 | port moresby
# Processing Record 15 of Set 10 | adre
# Processing Record 16 of Set 10 | bonfim
# Processing Record 17 of Set 10 | olovyannaya
# Processing Record 18 of Set 10 | trat
# Processing Record 19 of Set 10 | kamaishi
# City not found. Skipping...
# Processing Record 21 of Set 10 | havre-saint-pierre
# Processing Record 22 of Set 10 | siocon
# Processing Record 23 of Set 10 | dir
# Processing Record 24 of Set 10 | bismil
# Processing Record 25 of Set 10 | namatanai
# Processing Record 26 of Set 10 | edd
# Processing Record 27 of Set 10 | pabrade
# Processing Record 28 of Set 10 | ahuimanu
# City not found. Skipping...
# Processing Record 30 of Set 10 | homer
# Processing Record 31 of Set 10 | sept-iles
# City not found. Skipping...
# Processing Record 33 of Set 10 | kimbe
# Processing Record 34 of Set 10 | mongo
# Processing Record 35 of Set 10 | galle
# Processing Record 36 of Set 10 | luanda
# Processing Record 37 of Set 10 | almaznyy
# Processing Record 38 of Set 10 | salinopolis
# Processing Record 39 of Set 10 | nacala
# Processing Record 40 of Set 10 | panguna
# Processing Record 41 of Set 10 | vuktyl
# Processing Record 42 of Set 10 | nehe
# Processing Record 43 of Set 10 | abnub
# Processing Record 44 of Set 10 | san antonio
# Processing Record 45 of Set 10 | sharjah
# City not found. Skipping...
# Processing Record 47 of Set 10 | pangoa
# Processing Record 48 of Set 10 | manavgat
# Processing Record 49 of Set 10 | daru
# Processing Record 50 of Set 10 | paita
# Processing Record 1 of Set 11 | kurilsk
# Processing Record 2 of Set 11 | walvis bay
# Processing Record 3 of Set 11 | hun
# Processing Record 4 of Set 11 | kaniama
# Processing Record 5 of Set 11 | tibiri
# Processing Record 6 of Set 11 | turayf
# City not found. Skipping...
# Processing Record 8 of Set 11 | ponta do sol
# City not found. Skipping...
# Processing Record 10 of Set 11 | port hardy
# Processing Record 11 of Set 11 | mount gambier
# Processing Record 12 of Set 11 | serpneve
# Processing Record 13 of Set 11 | kharhial
# Processing Record 14 of Set 11 | northam
# Processing Record 15 of Set 11 | aykhal
# Processing Record 16 of Set 11 | saldanha
# Processing Record 17 of Set 11 | gamba
# Processing Record 18 of Set 11 | boende
# Processing Record 19 of Set 11 | afua
# Processing Record 20 of Set 11 | ust-omchug
# City not found. Skipping...
# Processing Record 22 of Set 11 | jerez
# Processing Record 23 of Set 11 | half moon bay
# Processing Record 24 of Set 11 | pedernales
# Processing Record 25 of Set 11 | winslow
# Processing Record 26 of Set 11 | talnakh
# Processing Record 27 of Set 11 | zhangjiakou
# Processing Record 28 of Set 11 | tamworth
# Processing Record 29 of Set 11 | beidao
# Processing Record 30 of Set 11 | sabzevar
# Processing Record 31 of Set 11 | bellmead
# City not found. Skipping...
# Processing Record 33 of Set 11 | tezu
# Processing Record 34 of Set 11 | kodinsk
# Processing Record 35 of Set 11 | tubuala
# Processing Record 36 of Set 11 | zhangye
# Processing Record 37 of Set 11 | jerantut
# Processing Record 38 of Set 11 | san vicente
# Processing Record 39 of Set 11 | san luis
# Processing Record 40 of Set 11 | valenca
# Processing Record 41 of Set 11 | urucui
# Processing Record 42 of Set 11 | plettenberg bay
# Processing Record 43 of Set 11 | nago
# Processing Record 44 of Set 11 | xuanzhou
# Processing Record 45 of Set 11 | asosa
# Processing Record 46 of Set 11 | port hueneme
# Processing Record 47 of Set 11 | bani walid
# City not found. Skipping...
# Processing Record 49 of Set 11 | sur
# Processing Record 50 of Set 11 | bell ville
# Processing Record 1 of Set 12 | san rafael
# Processing Record 2 of Set 12 | manaquiri
# Processing Record 3 of Set 12 | dargaville
# Processing Record 4 of Set 12 | batsfjord
# Processing Record 5 of Set 12 | melita
# Processing Record 6 of Set 12 | cejkovice
# Processing Record 7 of Set 12 | esmeraldas
# Processing Record 8 of Set 12 | san patricio
# City not found. Skipping...
# Processing Record 10 of Set 12 | pacific grove
# Processing Record 11 of Set 12 | lorengau
# Processing Record 12 of Set 12 | matara
# Processing Record 13 of Set 12 | kanigiri
# City not found. Skipping...
# Processing Record 15 of Set 12 | bonavista
# Processing Record 16 of Set 12 | podosinovets
# Processing Record 17 of Set 12 | naryan-mar
# Processing Record 18 of Set 12 | clarence town
# Processing Record 19 of Set 12 | baykit
# Processing Record 20 of Set 12 | brandon
# Processing Record 21 of Set 12 | wagar
# Processing Record 22 of Set 12 | hamilton
# Processing Record 23 of Set 12 | port-gentil
# City not found. Skipping...
# Processing Record 25 of Set 12 | belyy yar
# City not found. Skipping...
# Processing Record 27 of Set 12 | marzuq
# Processing Record 28 of Set 12 | ondangwa
# Processing Record 29 of Set 12 | rundu
# Processing Record 30 of Set 12 | williams lake
# City not found. Skipping...
# Processing Record 32 of Set 12 | bowen
# Processing Record 33 of Set 12 | pilot butte
# Processing Record 34 of Set 12 | cockburn town
# Processing Record 35 of Set 12 | podporozhye
# Processing Record 36 of Set 12 | garanhuns
# Processing Record 37 of Set 12 | gotsu
# Processing Record 38 of Set 12 | guhagar
# Processing Record 39 of Set 12 | riachao das neves
# Processing Record 40 of Set 12 | samana
# Processing Record 41 of Set 12 | norilsk
# Processing Record 42 of Set 12 | mayumba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.read_csv(output_data_file, encoding="ISO-8859-1")   #csv to df
weather_df = weather_df.dropna(how='any')   #cleaning data
weather_df.count()
# Out:
# City          516
# Cloudiness    516
# Country       516
# Date          516
# Humidity      516
# Lat           516
# Lng           516
# Max Temp      516
# Wind Speed    516
# dtype: int64

# %%
#presenting df
weather_df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Jamestown         100      AU  1570418543        69 -33.21  138.60
# 1      Kapaa          90      US  1570418543        94  22.08 -159.32
# 2    Ushuaia          40      AR  1570418543        80 -54.81  -68.31
# 3    Tautira          75      PF  1570418543        74 -17.73 -149.15
# 4  Busselton           3      AU  1570418475        62 -33.64  115.35
#
#    Max Temp  Wind Speed
# 0    57.740        5.58
# 1    82.400        5.10
# 2    35.600        5.70
# 3    78.800        5.70
# 4    64.004        0.89

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#using data frame columns to plot
plt.scatter(weather_df['Lat'], weather_df['Max Temp'], facecolors="lightblue", edgecolors="black")

#formatting
plt.title('City Latitude vs. Max Temperature (10/06/19)')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid(True)
plt.savefig('../images/temp_vs_lat.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#using data frame columns to plot
plt.scatter(weather_df['Lat'], weather_df['Humidity'], facecolors="lightblue", edgecolors="black")

#formatting
plt.title('City Latitude vs. Humidity (10/06/19)')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(True)
plt.savefig('../images/humidity_vs_lat.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#using data frame columns to plot
plt.scatter(weather_df['Lat'], weather_df['Cloudiness'], facecolors="lightblue", edgecolors="black")

#formatting
plt.title('City Latitude vs. Cloudiness (10/06/19)')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(True)
plt.savefig('../images/cloudiness_vs_lat.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#using data frame columns to plot
plt.scatter(weather_df['Lat'], weather_df['Wind Speed'], facecolors="lightblue", edgecolors="black")

#formatting
plt.title('City Latitude vs. Wind Speed (10/06/19)')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)
plt.savefig('../images/wind_speed_vs_lat.png')
plt.show()

# %% [markdown]
# ## Observable Trends
# * Despite the highest temperatures occuring between -40 and -20 degrees latitude, the distribution shows a central tendancy for the hottest cities to be at approximately 20 degrees latitude (i.e. not the equator) for this day, 10/06/19.
# * Wind speed appears to increase exponentially as the city nears closer to the south pole or the north pole.
# * From the lines of data points in the cloudiness plot, there is evidence to suggest that much of the data recorded was likely just a general estimation of the humidity (i.e. 0%, 20%, 40%, 75%, and 100%), while the rest of the data was recorded more precisely.
